# %% [markdown]
# # ASCII File Tree generator
#
# This is a simple script that generates a file tree in ASCII format. It is useful for generating a file tree for a project, or for generating a file tree for a directory.

# %%
import varname
import os

def _recursive_generate_ascii_tree(folder_path, folder_format="{}/", file_format="{}", middle_indent="├── ", passing_indent="│   ", last_indent="└── ", empty_indent="    ", include_first_folder=False):
    # include the first folder if specified
    if include_first_folder:
        folders = [os.path.abspath(folder_path)]
        files = []
    
    # get all folders and files in folder_path
    else:
        entries = sorted(entry.path for entry in os.scandir(folder_path))
        folders = [entry for entry in entries if os.path.isdir(entry)]
        files = [entry for entry in entries if os.path.isfile(entry)]

    # define a Line class for each line in the ASCII tree
    class Line:
        def __init__(self, text, is_folder=False):
            self.text = text
            self.is_folder = is_folder
    
    # break recursion if all folders are empty or no folders exist
    if all(not any(os.scandir(folder)) for folder in folders):
        tree = [Line(folder_format.format(os.path.basename(folder)), is_folder=True) for folder in folders]
        tree += [Line(file_format.format(os.path.basename(file)), is_folder=False) for file in files]

        return tree
    
    # go through all folders
    tree = []
    for folder in folders:
        tree.append(Line(folder_format.format(os.path.basename(folder)), is_folder=True))

        # get the subtree of the folder and add the right indents
        subtree = _recursive_generate_ascii_tree(folder, folder_format, file_format, middle_indent, passing_indent, last_indent, empty_indent)

        folder_indices = [i for i, line in enumerate(subtree) if line.is_folder]
        last_folder_index = folder_indices[-1] if len(folder_indices) > 0 else -1

        for i, line in enumerate(subtree):
            if line.is_folder:
                if i < last_folder_index:
                    line.text = middle_indent + line.text
                else:
                    line.text = last_indent + line.text
                line.is_folder = False
            else:
                if i < last_folder_index:
                    line.text = passing_indent + line.text
                else:
                    line.text = empty_indent + line.text
        tree += subtree
    
    # go through all files
    tree += [Line(file_format.format(os.path.basename(file)), is_folder=False) for file in files]
    
    return tree

def generate_ascii_tree(folder_path, include_first_folder=True, folder_format="{}/", file_format="{}", middle_indent="├── ", passing_indent="│   ", last_indent="└── ", empty_indent="    "):
    """
    Prints an ASCII file tree with box-drawing characters from a nested dictionary.

    Args:
        folder_path (str): The path to the folder to generate the tree for.
        include_first_folder (bool): Whether to include the first folder in the tree.
        folder_format (str): The format of the folder name. Must have exactly one {}.
        file_format (str): The format of the file name. Must have exactly one {}.
        middle_indent (str): The indent for a middle node.
        passing_indent (str): The indent for a passing node.
        last_indent (str): The indent for a last node.
        empty_indent (str): The indent for an empty node.

    Returns:
        str: The ASCII file tree.

    Raises:
        ValueError: If the folder format does not have exactly one {}.
        ValueError: If the file format does not have exactly one {}.
        ValueError: If the indents are not all the same length.
    """
    # handle bad inputs
    if folder_format.count("{}") != 1:
        raise ValueError(f"The provided value of {varname.nameof(folder_format)} does not have exactly one pair of curly braces 1x{r'{}'}: '{folder_format}'")
    if file_format.count("{}") != 1:
        raise ValueError(f"The provided value of {varname.nameof(file_format)} does not have exactly one pair of curly braces 1x{r'{}'}: '{folder_format}'")
    if not (len(middle_indent) == len(passing_indent) == len(last_indent) == len(empty_indent)):
        raise ValueError(f"The provided indents are not all the same length: len({varname.nameof(middle_indent)}) = {len(middle_indent)}, len({varname.nameof(passing_indent)}) = {len(passing_indent)}, len({varname.nameof(last_indent)}) = {len(last_indent)}, len({varname.nameof(empty_indent)}) = {len(empty_indent)})")
    
    tree = _recursive_generate_ascii_tree(folder_path, folder_format, file_format, middle_indent, passing_indent, last_indent, empty_indent, include_first_folder)

    return "\n".join(line.text for line in tree)

print(generate_ascii_tree("."))
# Out:
# simple-projects/
# ├── .git/
# │   ├── hooks/
# │   │       applypatch-msg.sample
# │   │       commit-msg.sample
# │   │       fsmonitor-watchman.sample
# │   │       post-update.sample
# │   │       pre-applypatch.sample
# │   │       pre-commit.sample
# │   │       pre-merge-commit.sample
# │   │       pre-push.sample
# │   │       pre-rebase.sample
# │   │       pre-receive.sample
# │   │       prepare-commit-msg.sample
# │   │       push-to-checkout.sample
# │   │       update.sample
# │   ├── info/
# │   │       exclude
# │   ├── logs/
# │   │   └── refs/
# │   │       ├── heads/
# │   │       │       master
# │   │       └── remotes/
# │   │           └── origin/
# │   │                   master
# │   │       HEAD
# │   ├── objects/
# │   │   ├── 00/
# │   │   │       9ab1a3cb0d0e39d9f772376561b56dc672b274
# │   │   │       c5fea270d62a6f8d4e8aa95f9f6ba575bace7a
# │   │   ├── 07/
# │   │   │       ea948007e8899ebb0433b8cde24b9095c6a9ef
# │   │   ├── 08/
# │   │   │       cba81f3bd9e5b1682180b659791b069abdf149
# │   │   ├── 0a/
# │   │   │       e07b035c59a3714fc70821373504a8c85931ee
# │   │   ├── 0e/
# │   │   │       676fef27b530aa966ccb49877fe1f02ea74053
# │   │   ├── 27/
# │   │   │       473f3f895913643f814c7676d1e00b0b8cea5d
# │   │   ├── 2d/
# │   │   │       910d212d51ad8367dfa6ae54dea97df3e7d8ff
# │   │   ├── 2f/
# │   │   │       dd252c3b7122a8ed52f4d4462b6627dbc96228
# │   │   ├── 32/
# │   │   │       ba65097d6ac963f928513bcbc4889b5bf144a0
# │   │   │       f8d869c91f220418d0a679381bdd32af3e7493
# │   │   ├── 33/
# │   │   │       3a7fee2802f4e8af22e5b2ac788d260d0ccba8
# │   │   ├── 3c/
# │   │   │       2308d2495835feca3aeabee20b12da03d2e688
# │   │   ├── 45/
# │   │   │       4e4371ee88d5b0276d8a33c673c9f1983c2672
# │   │   ├── 59/
# │   │   │       7d8e273441a286252ed91fce142cce734c7873
# │   │   ├── 6f/
# │   │   │       52b2d456ad69802e77c1a0cc20f9480abcbb0a
# │   │   │       e47afed69ecdd459a62a6cceb5ce5221ace354
# │   │   ├── 70/
# │   │   │       4a1fceac536f72ecb624efaf448c7c70f5903d
# │   │   ├── 71/
# │   │   │       261df79b392dcf9f0a8477952f0188fa103c25
# │   │   ├── 75/
# │   │   │       8d04ddf0fc5815070fef61b29e8e6b3857b3c4
# │   │   ├── 76/
# │   │   │       011ef71e96c903a542e2df16c254ea815a4b46
# │   │   ├── 87/
# │   │   │       8158a496de7fbab4f8ffb8e9272b8d10182073
# │   │   ├── 92/
# │   │   │       30e7ee482476545a26df9d7d0caea11bd03f1e
# │   │   ├── 9f/
# │   │   │       626fe44770a1c06a3c36c594589e474d011f7d
# │   │   ├── a3/
# │   │   │       166ee938918704619f3ac983980fa2f1315962
# │   │   ├── aa/
# │   │   │       f57f7045014e5eff793fded967135551578d8a
# │   │   ├── b6/
# │   │   │       1d0643a53dd25912bcd9f9682988a568ed8e0a
# │   │   ├── c8/
# │   │   │       2524547c03a96aa4b77db1f6a9aebaecdf0104
# │   │   ├── ce/
# │   │   │       aaced45946f3998b665ee5db61cd937857211e
# │   │   ├── ee/
# │   │   │       903c1bc35b45f96fe5411a82365a1f8d6bf7a4
# │   │   ├── f2/
# │   │   │       c02877e93d69c414d717dfaa9623c1f373fc9a
# │   │   ├── info/
# │   │   └── pack/
# │   └── refs/
# │       ├── heads/
# │       │       master
# │       ├── remotes/
# │       │   └── origin/
# │       │           master
# │       └── tags/
# │       COMMIT_EDITMSG
# │       FETCH_HEAD
# │       HEAD
# │       ORIG_HEAD
# │       config
# │       description
# │       index
# ├── __pycache__/
# │       search.cpython-311.pyc
# ├── empty/
# ├── ignore/
# │       area_single_column.png
# │       experiments_double_column.png
# │       labels_double_column.png
# │       matrix_single_column.png
# │       resized_area_single_column.png
# │       resized_experiments_double_column.png
# │       resized_labels_double_column.png
# │       resized_matrix_single_column.png
# │       resized_samples_single_column.png
# │       samples_single_column.png
# └── simple-projects/
#     ├── Include/
#     ├── Lib/
#     │   └── site-packages/
#     │       ├── IPython/
#     │       │   ├── __pycache__/
#     │       │   │       __init__.cpython-311.pyc
#     │       │   │       __main__.cpython-311.pyc
#     │       │   │       conftest.cpython-311.pyc
#     │       │   │       consoleapp.cpython-311.pyc
#     │       │   │       display.cpython-311.pyc
#     │       │   │       paths.cpython-311.pyc
#     │       │   ├── core/
#     │       │   │   ├── __pycache__/
#     │       │   │   │       __init__.cpython-311.pyc
#     │       │   │   │       alias.cpython-311.pyc
#     │       │   │   │       application.cpython-311.pyc
#     │       │   │   │       async_helpers.cpython-311.pyc
#     │       │   │   │       autocall.cpython-311.pyc
#     │       │   │   │       builtin_trap.cpython-311.pyc
#     │       │   │   │       compilerop.cpython-311.pyc
#     │       │   │   │       completer.cpython-311.pyc
#     │       │   │   │       completerlib.cpython-311.pyc
#     │       │   │   │       crashhandler.cpython-311.pyc
#     │       │   │   │       debugger.cpython-311.pyc
#     │       │   │   │       display.cpython-311.pyc
#     │       │   │   │       display_functions.cpython-311.pyc
#     │       │   │   │       display_trap.cpython-311.pyc
#     │       │   │   │       displayhook.cpython-311.pyc
#     │       │   │   │       displaypub.cpython-311.pyc
#     │       │   │   │       error.cpython-311.pyc
#     │       │   │   │       events.cpython-311.pyc
#     │       │   │   │       excolors.cpython-311.pyc
#     │       │   │   │       extensions.cpython-311.pyc
#     │       │   │   │       formatters.cpython-311.pyc
#     │       │   │   │       getipython.cpython-311.pyc
#     │       │   │   │       history.cpython-311.pyc
#     │       │   │   │       historyapp.cpython-311.pyc
#     │       │   │   │       hooks.cpython-311.pyc
#     │       │   │   │       inputsplitter.cpython-311.pyc
#     │       │   │   │       inputtransformer.cpython-311.pyc
#     │       │   │   │       inputtransformer2.cpython-311.pyc
#     │       │   │   │       interactiveshell.cpython-311.pyc
#     │       │   │   │       latex_symbols.cpython-311.pyc
#     │       │   │   │       logger.cpython-311.pyc
#     │       │   │   │       macro.cpython-311.pyc
#     │       │   │   │       magic.cpython-311.pyc
#     │       │   │   │       magic_arguments.cpython-311.pyc
#     │       │   │   │       oinspect.cpython-311.pyc
#     │       │   │   │       page.cpython-311.pyc
#     │       │   │   │       payload.cpython-311.pyc
#     │       │   │   │       payloadpage.cpython-311.pyc
#     │       │   │   │       prefilter.cpython-311.pyc
#     │       │   │   │       profileapp.cpython-311.pyc
#     │       │   │   │       profiledir.cpython-311.pyc
#     │       │   │   │       prompts.cpython-311.pyc
#     │       │   │   │       pylabtools.cpython-311.pyc
#     │       │   │   │       release.cpython-311.pyc
#     │       │   │   │       shellapp.cpython-311.pyc
#     │       │   │   │       splitinput.cpython-311.pyc
#     │       │   │   │       ultratb.cpython-311.pyc
#     │       │   │   │       usage.cpython-311.pyc
#     │       │   │   ├── magics/
#     │       │   │   │   └── __pycache__/
#     │       │   │   │           __init__.cpython-311.pyc
#     │       │   │   │           auto.cpython-311.pyc
#     │       │   │   │           basic.cpython-311.pyc
#     │       │   │   │           code.cpython-311.pyc
#     │       │   │   │           config.cpython-311.pyc
#     │       │   │   │           display.cpython-311.pyc
#     │       │   │   │           execution.cpython-311.pyc
#     │       │   │   │           extension.cpython-311.pyc
#     │       │   │   │           history.cpython-311.pyc
#     │       │   │   │           logging.cpython-311.pyc
#     │       │   │   │           namespace.cpython-311.pyc
#     │       │   │   │           osm.cpython-311.pyc
#     │       │   │   │           packaging.cpython-311.pyc
#     │       │   │   │           pylab.cpython-311.pyc
#     │       │   │   │           script.cpython-311.pyc
#     │       │   │   │       __init__.py
#     │       │   │   │       auto.py
#     │       │   │   │       basic.py
#     │       │   │   │       code.py
#     │       │   │   │       config.py
#     │       │   │   │       display.py
#     │       │   │   │       execution.py
#     │       │   │   │       extension.py
#     │       │   │   │       history.py
#     │       │   │   │       logging.py
#     │       │   │   │       namespace.py
#     │       │   │   │       osm.py
#     │       │   │   │       packaging.py
#     │       │   │   │       pylab.py
#     │       │   │   │       script.py
#     │       │   │   ├── profile/
#     │       │   │   │       README_STARTUP
#     │       │   │   └── tests/
#     │       │   │       ├── __pycache__/
#     │       │   │       │       __init__.cpython-311.pyc
#     │       │   │       │       bad_all.cpython-311.pyc
#     │       │   │       │       nonascii.cpython-311.pyc
#     │       │   │       │       nonascii2.cpython-311.pyc
#     │       │   │       │       print_argv.cpython-311.pyc
#     │       │   │       │       refbug.cpython-311.pyc
#     │       │   │       │       simpleerr.cpython-311.pyc
#     │       │   │       │       tclass.cpython-311.pyc
#     │       │   │       │       test_alias.cpython-311.pyc
#     │       │   │       │       test_application.cpython-311.pyc
#     │       │   │       │       test_async_helpers.cpython-311.pyc
#     │       │   │       │       test_autocall.cpython-311.pyc
#     │       │   │       │       test_compilerop.cpython-311.pyc
#     │       │   │       │       test_completer.cpython-311.pyc
#     │       │   │       │       test_completerlib.cpython-311.pyc
#     │       │   │       │       test_debugger.cpython-311.pyc
#     │       │   │       │       test_display.cpython-311.pyc
#     │       │   │       │       test_displayhook.cpython-311.pyc
#     │       │   │       │       test_events.cpython-311.pyc
#     │       │   │       │       test_extension.cpython-311.pyc
#     │       │   │       │       test_formatters.cpython-311.pyc
#     │       │   │       │       test_handlers.cpython-311.pyc
#     │       │   │       │       test_history.cpython-311.pyc
#     │       │   │       │       test_hooks.cpython-311.pyc
#     │       │   │       │       test_imports.cpython-311.pyc
#     │       │   │       │       test_inputsplitter.cpython-311.pyc
#     │       │   │       │       test_inputtransformer.cpython-311.pyc
#     │       │   │       │       test_inputtransformer2.cpython-311.pyc
#     │       │   │       │       test_inputtransformer2_line.cpython-311.pyc
#     │       │   │       │       test_interactiveshell.cpython-311.pyc
#     │       │   │       │       test_iplib.cpython-311.pyc
#     │       │   │       │       test_logger.cpython-311.pyc
#     │       │   │       │       test_magic.cpython-311.pyc
#     │       │   │       │       test_magic_arguments.cpython-311.pyc
#     │       │   │       │       test_magic_terminal.cpython-311.pyc
#     │       │   │       │       test_oinspect.cpython-311.pyc
#     │       │   │       │       test_page.cpython-311.pyc
#     │       │   │       │       test_paths.cpython-311.pyc
#     │       │   │       │       test_prefilter.cpython-311.pyc
#     │       │   │       │       test_profile.cpython-311.pyc
#     │       │   │       │       test_prompts.cpython-311.pyc
#     │       │   │       │       test_pylabtools.cpython-311.pyc
#     │       │   │       │       test_run.cpython-311.pyc
#     │       │   │       │       test_shellapp.cpython-311.pyc
#     │       │   │       │       test_splitinput.cpython-311.pyc
#     │       │   │       │       test_ultratb.cpython-311.pyc
#     │       │   │       └── daft_extension/
#     │       │   │           └── __pycache__/
#     │       │   │                   daft_extension.cpython-311.pyc
#     │       │   │               daft_extension.py
#     │       │   │           2x2.jpg
#     │       │   │           2x2.png
#     │       │   │           __init__.py
#     │       │   │           bad_all.py
#     │       │   │           nonascii.py
#     │       │   │           nonascii2.py
#     │       │   │           print_argv.py
#     │       │   │           refbug.py
#     │       │   │           simpleerr.py
#     │       │   │           tclass.py
#     │       │   │           test_alias.py
#     │       │   │           test_application.py
#     │       │   │           test_async_helpers.py
#     │       │   │           test_autocall.py
#     │       │   │           test_compilerop.py
#     │       │   │           test_completer.py
#     │       │   │           test_completerlib.py
#     │       │   │           test_debugger.py
#     │       │   │           test_display.py
#     │       │   │           test_displayhook.py
#     │       │   │           test_events.py
#     │       │   │           test_extension.py
#     │       │   │           test_formatters.py
#     │       │   │           test_handlers.py
#     │       │   │           test_history.py
#     │       │   │           test_hooks.py
#     │       │   │           test_imports.py
#     │       │   │           test_inputsplitter.py
#     │       │   │           test_inputtransformer.py
#     │       │   │           test_inputtransformer2.py
#     │       │   │           test_inputtransformer2_line.py
#     │       │   │           test_interactiveshell.py
#     │       │   │           test_iplib.py
#     │       │   │           test_logger.py
#     │       │   │           test_magic.py
#     │       │   │           test_magic_arguments.py
#     │       │   │           test_magic_terminal.py
#     │       │   │           test_oinspect.py
#     │       │   │           test_page.py
#     │       │   │           test_paths.py
#     │       │   │           test_prefilter.py
#     │       │   │           test_profile.py
#     │       │   │           test_prompts.py
#     │       │   │           test_pylabtools.py
#     │       │   │           test_run.py
#     │       │   │           test_shellapp.py
#     │       │   │           test_splitinput.py
#     │       │   │           test_ultratb.py
#     │       │   │       __init__.py
#     │       │   │       alias.py
#     │       │   │       application.py
#     │       │   │       async_helpers.py
#     │       │   │       autocall.py
#     │       │   │       builtin_trap.py
#     │       │   │       compilerop.py
#     │       │   │       completer.py
#     │       │   │       completerlib.py
#     │       │   │       crashhandler.py
#     │       │   │       debugger.py
#     │       │   │       display.py
#     │       │   │       display_functions.py
#     │       │   │       display_trap.py
#     │       │   │       displayhook.py
#     │       │   │       displaypub.py
#     │       │   │       error.py
#     │       │   │       events.py
#     │       │   │       excolors.py
#     │       │   │       extensions.py
#     │       │   │       formatters.py
#     │       │   │       getipython.py
#     │       │   │       history.py
#     │       │   │       historyapp.py
#     │       │   │       hooks.py
#     │       │   │       inputsplitter.py
#     │       │   │       inputtransformer.py
#     │       │   │       inputtransformer2.py
#     │       │   │       interactiveshell.py
#     │       │   │       latex_symbols.py
#     │       │   │       logger.py
#     │       │   │       macro.py
#     │       │   │       magic.py
#     │       │   │       magic_arguments.py
#     │       │   │       oinspect.py
#     │       │   │       page.py
#     │       │   │       payload.py
#     │       │   │       payloadpage.py
#     │       │   │       prefilter.py
#     │       │   │       profileapp.py
#     │       │   │       profiledir.py
#     │       │   │       prompts.py
#     │       │   │       pylabtools.py
#     │       │   │       release.py
#     │       │   │       shellapp.py
#     │       │   │       splitinput.py
#     │       │   │       ultratb.py
#     │       │   │       usage.py
#     │       │   ├── extensions/
#     │       │   │   ├── __pycache__/
#     │       │   │   │       __init__.cpython-311.pyc
#     │       │   │   │       autoreload.cpython-311.pyc
#     │       │   │   │       storemagic.cpython-311.pyc
#     │       │   │   └── tests/
#     │       │   │       └── __pycache__/
#     │       │   │               __init__.cpython-311.pyc
#     │       │   │               test_autoreload.cpython-311.pyc
#     │       │   │               test_storemagic.cpython-311.pyc
#     │       │   │           __init__.py
#     │       │   │           test_autoreload.py
#     │       │   │           test_storemagic.py
#     │       │   │       __init__.py
#     │       │   │       autoreload.py
#     │       │   │       storemagic.py
#     │       │   ├── external/
#     │       │   │   ├── __pycache__/
#     │       │   │   │       __init__.cpython-311.pyc
#     │       │   │   │       qt_for_kernel.cpython-311.pyc
#     │       │   │   │       qt_loaders.cpython-311.pyc
#     │       │   │   └── tests/
#     │       │   │       └── __pycache__/
#     │       │   │               __init__.cpython-311.pyc
#     │       │   │               test_qt_loaders.cpython-311.pyc
#     │       │   │           __init__.py
#     │       │   │           test_qt_loaders.py
#     │       │   │       __init__.py
#     │       │   │       qt_for_kernel.py
#     │       │   │       qt_loaders.py
#     │       │   ├── lib/
#     │       │   │   ├── __pycache__/
#     │       │   │   │       __init__.cpython-311.pyc
#     │       │   │   │       backgroundjobs.cpython-311.pyc
#     │       │   │   │       clipboard.cpython-311.pyc
#     │       │   │   │       deepreload.cpython-311.pyc
#     │       │   │   │       demo.cpython-311.pyc
#     │       │   │   │       display.cpython-311.pyc
#     │       │   │   │       editorhooks.cpython-311.pyc
#     │       │   │   │       guisupport.cpython-311.pyc
#     │       │   │   │       latextools.cpython-311.pyc
#     │       │   │   │       lexers.cpython-311.pyc
#     │       │   │   │       pretty.cpython-311.pyc
#     │       │   │   └── tests/
#     │       │   │       └── __pycache__/
#     │       │   │               __init__.cpython-311.pyc
#     │       │   │               test_backgroundjobs.cpython-311.pyc
#     │       │   │               test_clipboard.cpython-311.pyc
#     │       │   │               test_deepreload.cpython-311.pyc
#     │       │   │               test_display.cpython-311.pyc
#     │       │   │               test_editorhooks.cpython-311.pyc
#     │       │   │               test_imports.cpython-311.pyc
#     │       │   │               test_latextools.cpython-311.pyc
#     │       │   │               test_lexers.cpython-311.pyc
#     │       │   │               test_pretty.cpython-311.pyc
#     │       │   │           __init__.py
#     │       │   │           test.wav
#     │       │   │           test_backgroundjobs.py
#     │       │   │           test_clipboard.py
#     │       │   │           test_deepreload.py
#     │       │   │           test_display.py
#     │       │   │           test_editorhooks.py
#     │       │   │           test_imports.py
#     │       │   │           test_latextools.py
#     │       │   │           test_lexers.py
#     │       │   │           test_pretty.py
#     │       │   │       __init__.py
#     │       │   │       backgroundjobs.py
#     │       │   │       clipboard.py
#     │       │   │       deepreload.py
#     │       │   │       demo.py
#     │       │   │       display.py
#     │       │   │       editorhooks.py
#     │       │   │       guisupport.py
#     │       │   │       latextools.py
#     │       │   │       lexers.py
#     │       │   │       pretty.py
#     │       │   ├── sphinxext/
#     │       │   │   └── __pycache__/
#     │       │   │           __init__.cpython-311.pyc
#     │       │   │           custom_doctests.cpython-311.pyc
#     │       │   │           ipython_console_highlighting.cpython-311.pyc
#     │       │   │           ipython_directive.cpython-311.pyc
#     │       │   │       __init__.py
#     │       │   │       custom_doctests.py
#     │       │   │       ipython_console_highlighting.py
#     │       │   │       ipython_directive.py
#     │       │   ├── terminal/
#     │       │   │   ├── __pycache__/
#     │       │   │   │       __init__.cpython-311.pyc
#     │       │   │   │       console.cpython-311.pyc
#     │       │   │   │       debugger.cpython-311.pyc
#     │       │   │   │       embed.cpython-311.pyc
#     │       │   │   │       interactiveshell.cpython-311.pyc
#     │       │   │   │       ipapp.cpython-311.pyc
#     │       │   │   │       magics.cpython-311.pyc
#     │       │   │   │       prompts.cpython-311.pyc
#     │       │   │   │       ptutils.cpython-311.pyc
#     │       │   │   │       shortcuts.cpython-311.pyc
#     │       │   │   ├── pt_inputhooks/
#     │       │   │   │   └── __pycache__/
#     │       │   │   │           __init__.cpython-311.pyc
#     │       │   │   │           asyncio.cpython-311.pyc
#     │       │   │   │           glut.cpython-311.pyc
#     │       │   │   │           gtk.cpython-311.pyc
#     │       │   │   │           gtk3.cpython-311.pyc
#     │       │   │   │           gtk4.cpython-311.pyc
#     │       │   │   │           osx.cpython-311.pyc
#     │       │   │   │           pyglet.cpython-311.pyc
#     │       │   │   │           qt.cpython-311.pyc
#     │       │   │   │           tk.cpython-311.pyc
#     │       │   │   │           wx.cpython-311.pyc
#     │       │   │   │       __init__.py
#     │       │   │   │       asyncio.py
#     │       │   │   │       glut.py
#     │       │   │   │       gtk.py
#     │       │   │   │       gtk3.py
#     │       │   │   │       gtk4.py
#     │       │   │   │       osx.py
#     │       │   │   │       pyglet.py
#     │       │   │   │       qt.py
#     │       │   │   │       tk.py
#     │       │   │   │       wx.py
#     │       │   │   └── tests/
#     │       │   │       └── __pycache__/
#     │       │   │               __init__.cpython-311.pyc
#     │       │   │               test_debug_magic.cpython-311.pyc
#     │       │   │               test_embed.cpython-311.pyc
#     │       │   │               test_help.cpython-311.pyc
#     │       │   │               test_interactivshell.cpython-311.pyc
#     │       │   │           __init__.py
#     │       │   │           test_debug_magic.py
#     │       │   │           test_embed.py
#     │       │   │           test_help.py
#     │       │   │           test_interactivshell.py
#     │       │   │       __init__.py
#     │       │   │       console.py
#     │       │   │       debugger.py
#     │       │   │       embed.py
#     │       │   │       interactiveshell.py
#     │       │   │       ipapp.py
#     │       │   │       magics.py
#     │       │   │       prompts.py
#     │       │   │       ptutils.py
#     │       │   │       shortcuts.py
#     │       │   ├── testing/
#     │       │   │   ├── __pycache__/
#     │       │   │   │       __init__.cpython-311.pyc
#     │       │   │   │       decorators.cpython-311.pyc
#     │       │   │   │       globalipapp.cpython-311.pyc
#     │       │   │   │       ipunittest.cpython-311.pyc
#     │       │   │   │       skipdoctest.cpython-311.pyc
#     │       │   │   │       tools.cpython-311.pyc
#     │       │   │   ├── plugin/
#     │       │   │   │   └── __pycache__/
#     │       │   │   │           __init__.cpython-311.pyc
#     │       │   │   │           dtexample.cpython-311.pyc
#     │       │   │   │           ipdoctest.cpython-311.pyc
#     │       │   │   │           pytest_ipdoctest.cpython-311.pyc
#     │       │   │   │           setup.cpython-311.pyc
#     │       │   │   │           simple.cpython-311.pyc
#     │       │   │   │           simplevars.cpython-311.pyc
#     │       │   │   │           test_ipdoctest.cpython-311.pyc
#     │       │   │   │           test_refs.cpython-311.pyc
#     │       │   │   │       README.txt
#     │       │   │   │       __init__.py
#     │       │   │   │       dtexample.py
#     │       │   │   │       ipdoctest.py
#     │       │   │   │       pytest_ipdoctest.py
#     │       │   │   │       setup.py
#     │       │   │   │       simple.py
#     │       │   │   │       simplevars.py
#     │       │   │   │       test_combo.txt
#     │       │   │   │       test_example.txt
#     │       │   │   │       test_exampleip.txt
#     │       │   │   │       test_ipdoctest.py
#     │       │   │   │       test_refs.py
#     │       │   │   └── tests/
#     │       │   │       └── __pycache__/
#     │       │   │               __init__.cpython-311.pyc
#     │       │   │               test_decorators.cpython-311.pyc
#     │       │   │               test_ipunittest.cpython-311.pyc
#     │       │   │               test_tools.cpython-311.pyc
#     │       │   │           __init__.py
#     │       │   │           test_decorators.py
#     │       │   │           test_ipunittest.py
#     │       │   │           test_tools.py
#     │       │   │       __init__.py
#     │       │   │       decorators.py
#     │       │   │       globalipapp.py
#     │       │   │       ipunittest.py
#     │       │   │       skipdoctest.py
#     │       │   │       tools.py
#     │       │   └── utils/
#     │       │       ├── __pycache__/
#     │       │       │       PyColorize.cpython-311.pyc
#     │       │       │       __init__.cpython-311.pyc
#     │       │       │       _process_cli.cpython-311.pyc
#     │       │       │       _process_common.cpython-311.pyc
#     │       │       │       _process_posix.cpython-311.pyc
#     │       │       │       _process_win32.cpython-311.pyc
#     │       │       │       _process_win32_controller.cpython-311.pyc
#     │       │       │       _sysinfo.cpython-311.pyc
#     │       │       │       capture.cpython-311.pyc
#     │       │       │       colorable.cpython-311.pyc
#     │       │       │       coloransi.cpython-311.pyc
#     │       │       │       contexts.cpython-311.pyc
#     │       │       │       daemonize.cpython-311.pyc
#     │       │       │       data.cpython-311.pyc
#     │       │       │       decorators.cpython-311.pyc
#     │       │       │       dir2.cpython-311.pyc
#     │       │       │       docs.cpython-311.pyc
#     │       │       │       encoding.cpython-311.pyc
#     │       │       │       eventful.cpython-311.pyc
#     │       │       │       frame.cpython-311.pyc
#     │       │       │       generics.cpython-311.pyc
#     │       │       │       importstring.cpython-311.pyc
#     │       │       │       io.cpython-311.pyc
#     │       │       │       ipstruct.cpython-311.pyc
#     │       │       │       jsonutil.cpython-311.pyc
#     │       │       │       localinterfaces.cpython-311.pyc
#     │       │       │       log.cpython-311.pyc
#     │       │       │       module_paths.cpython-311.pyc
#     │       │       │       openpy.cpython-311.pyc
#     │       │       │       path.cpython-311.pyc
#     │       │       │       process.cpython-311.pyc
#     │       │       │       py3compat.cpython-311.pyc
#     │       │       │       sentinel.cpython-311.pyc
#     │       │       │       shimmodule.cpython-311.pyc
#     │       │       │       signatures.cpython-311.pyc
#     │       │       │       strdispatch.cpython-311.pyc
#     │       │       │       sysinfo.cpython-311.pyc
#     │       │       │       syspathcontext.cpython-311.pyc
#     │       │       │       tempdir.cpython-311.pyc
#     │       │       │       terminal.cpython-311.pyc
#     │       │       │       text.cpython-311.pyc
#     │       │       │       timing.cpython-311.pyc
#     │       │       │       tokenutil.cpython-311.pyc
#     │       │       │       traitlets.cpython-311.pyc
#     │       │       │       tz.cpython-311.pyc
#     │       │       │       ulinecache.cpython-311.pyc
#     │       │       │       version.cpython-311.pyc
#     │       │       │       wildcard.cpython-311.pyc
#     │       │       └── tests/
#     │       │           └── __pycache__/
#     │       │                   __init__.cpython-311.pyc
#     │       │                   test_capture.cpython-311.pyc
#     │       │                   test_decorators.cpython-311.pyc
#     │       │                   test_deprecated.cpython-311.pyc
#     │       │                   test_dir2.cpython-311.pyc
#     │       │                   test_imports.cpython-311.pyc
#     │       │                   test_importstring.cpython-311.pyc
#     │       │                   test_io.cpython-311.pyc
#     │       │                   test_module_paths.cpython-311.pyc
#     │       │                   test_openpy.cpython-311.pyc
#     │       │                   test_path.cpython-311.pyc
#     │       │                   test_process.cpython-311.pyc
#     │       │                   test_pycolorize.cpython-311.pyc
#     │       │                   test_shimmodule.cpython-311.pyc
#     │       │                   test_sysinfo.cpython-311.pyc
#     │       │                   test_tempdir.cpython-311.pyc
#     │       │                   test_text.cpython-311.pyc
#     │       │                   test_tokenutil.cpython-311.pyc
#     │       │                   test_wildcard.cpython-311.pyc
#     │       │               __init__.py
#     │       │               test_capture.py
#     │       │               test_decorators.py
#     │       │               test_deprecated.py
#     │       │               test_dir2.py
#     │       │               test_imports.py
#     │       │               test_importstring.py
#     │       │               test_io.py
#     │       │               test_module_paths.py
#     │       │               test_openpy.py
#     │       │               test_path.py
#     │       │               test_process.py
#     │       │               test_pycolorize.py
#     │       │               test_shimmodule.py
#     │       │               test_sysinfo.py
#     │       │               test_tempdir.py
#     │       │               test_text.py
#     │       │               test_tokenutil.py
#     │       │               test_wildcard.py
#     │       │           PyColorize.py
#     │       │           __init__.py
#     │       │           _process_cli.py
#     │       │           _process_common.py
#     │       │           _process_posix.py
#     │       │           _process_win32.py
#     │       │           _process_win32_controller.py
#     │       │           _sysinfo.py
#     │       │           capture.py
#     │       │           colorable.py
#     │       │           coloransi.py
#     │       │           contexts.py
#     │       │           daemonize.py
#     │       │           data.py
#     │       │           decorators.py
#     │       │           dir2.py
#     │       │           docs.py
#     │       │           encoding.py
#     │       │           eventful.py
#     │       │           frame.py
#     │       │           generics.py
#     │       │           importstring.py
#     │       │           io.py
#     │       │           ipstruct.py
#     │       │           jsonutil.py
#     │       │           localinterfaces.py
#     │       │           log.py
#     │       │           module_paths.py
#     │       │           openpy.py
#     │       │           path.py
#     │       │           process.py
#     │       │           py3compat.py
#     │       │           sentinel.py
#     │       │           shimmodule.py
#     │       │           signatures.py
#     │       │           strdispatch.py
#     │       │           sysinfo.py
#     │       │           syspathcontext.py
#     │       │           tempdir.py
#     │       │           terminal.py
#     │       │           text.py
#     │       │           timing.py
#     │       │           tokenutil.py
#     │       │           traitlets.py
#     │       │           tz.py
#     │       │           ulinecache.py
#     │       │           version.py
#     │       │           wildcard.py
#     │       │       __init__.py
#     │       │       __main__.py
#     │       │       conftest.py
#     │       │       consoleapp.py
#     │       │       display.py
#     │       │       paths.py
#     │       ├── PIL/
#     │       │   └── __pycache__/
#     │       │           BdfFontFile.cpython-311.pyc
#     │       │           BlpImagePlugin.cpython-311.pyc
#     │       │           BmpImagePlugin.cpython-311.pyc
#     │       │           BufrStubImagePlugin.cpython-311.pyc
#     │       │           ContainerIO.cpython-311.pyc
#     │       │           CurImagePlugin.cpython-311.pyc
#     │       │           DcxImagePlugin.cpython-311.pyc
#     │       │           DdsImagePlugin.cpython-311.pyc
#     │       │           EpsImagePlugin.cpython-311.pyc
#     │       │           ExifTags.cpython-311.pyc
#     │       │           FitsImagePlugin.cpython-311.pyc
#     │       │           FitsStubImagePlugin.cpython-311.pyc
#     │       │           FliImagePlugin.cpython-311.pyc
#     │       │           FontFile.cpython-311.pyc
#     │       │           FpxImagePlugin.cpython-311.pyc
#     │       │           FtexImagePlugin.cpython-311.pyc
#     │       │           GbrImagePlugin.cpython-311.pyc
#     │       │           GdImageFile.cpython-311.pyc
#     │       │           GifImagePlugin.cpython-311.pyc
#     │       │           GimpGradientFile.cpython-311.pyc
#     │       │           GimpPaletteFile.cpython-311.pyc
#     │       │           GribStubImagePlugin.cpython-311.pyc
#     │       │           Hdf5StubImagePlugin.cpython-311.pyc
#     │       │           IcnsImagePlugin.cpython-311.pyc
#     │       │           IcoImagePlugin.cpython-311.pyc
#     │       │           ImImagePlugin.cpython-311.pyc
#     │       │           Image.cpython-311.pyc
#     │       │           ImageChops.cpython-311.pyc
#     │       │           ImageCms.cpython-311.pyc
#     │       │           ImageColor.cpython-311.pyc
#     │       │           ImageDraw.cpython-311.pyc
#     │       │           ImageDraw2.cpython-311.pyc
#     │       │           ImageEnhance.cpython-311.pyc
#     │       │           ImageFile.cpython-311.pyc
#     │       │           ImageFilter.cpython-311.pyc
#     │       │           ImageFont.cpython-311.pyc
#     │       │           ImageGrab.cpython-311.pyc
#     │       │           ImageMath.cpython-311.pyc
#     │       │           ImageMode.cpython-311.pyc
#     │       │           ImageMorph.cpython-311.pyc
#     │       │           ImageOps.cpython-311.pyc
#     │       │           ImagePalette.cpython-311.pyc
#     │       │           ImagePath.cpython-311.pyc
#     │       │           ImageQt.cpython-311.pyc
#     │       │           ImageSequence.cpython-311.pyc
#     │       │           ImageShow.cpython-311.pyc
#     │       │           ImageStat.cpython-311.pyc
#     │       │           ImageTk.cpython-311.pyc
#     │       │           ImageTransform.cpython-311.pyc
#     │       │           ImageWin.cpython-311.pyc
#     │       │           ImtImagePlugin.cpython-311.pyc
#     │       │           IptcImagePlugin.cpython-311.pyc
#     │       │           Jpeg2KImagePlugin.cpython-311.pyc
#     │       │           JpegImagePlugin.cpython-311.pyc
#     │       │           JpegPresets.cpython-311.pyc
#     │       │           McIdasImagePlugin.cpython-311.pyc
#     │       │           MicImagePlugin.cpython-311.pyc
#     │       │           MpegImagePlugin.cpython-311.pyc
#     │       │           MpoImagePlugin.cpython-311.pyc
#     │       │           MspImagePlugin.cpython-311.pyc
#     │       │           PSDraw.cpython-311.pyc
#     │       │           PaletteFile.cpython-311.pyc
#     │       │           PalmImagePlugin.cpython-311.pyc
#     │       │           PcdImagePlugin.cpython-311.pyc
#     │       │           PcfFontFile.cpython-311.pyc
#     │       │           PcxImagePlugin.cpython-311.pyc
#     │       │           PdfImagePlugin.cpython-311.pyc
#     │       │           PdfParser.cpython-311.pyc
#     │       │           PixarImagePlugin.cpython-311.pyc
#     │       │           PngImagePlugin.cpython-311.pyc
#     │       │           PpmImagePlugin.cpython-311.pyc
#     │       │           PsdImagePlugin.cpython-311.pyc
#     │       │           PyAccess.cpython-311.pyc
#     │       │           SgiImagePlugin.cpython-311.pyc
#     │       │           SpiderImagePlugin.cpython-311.pyc
#     │       │           SunImagePlugin.cpython-311.pyc
#     │       │           TarIO.cpython-311.pyc
#     │       │           TgaImagePlugin.cpython-311.pyc
#     │       │           TiffImagePlugin.cpython-311.pyc
#     │       │           TiffTags.cpython-311.pyc
#     │       │           WalImageFile.cpython-311.pyc
#     │       │           WebPImagePlugin.cpython-311.pyc
#     │       │           WmfImagePlugin.cpython-311.pyc
#     │       │           XVThumbImagePlugin.cpython-311.pyc
#     │       │           XbmImagePlugin.cpython-311.pyc
#     │       │           XpmImagePlugin.cpython-311.pyc
#     │       │           __init__.cpython-311.pyc
#     │       │           __main__.cpython-311.pyc
#     │       │           _binary.cpython-311.pyc
#     │       │           _deprecate.cpython-311.pyc
#     │       │           _tkinter_finder.cpython-311.pyc
#     │       │           _util.cpython-311.pyc
#     │       │           _version.cpython-311.pyc
#     │       │           features.cpython-311.pyc
#     │       │       BdfFontFile.py
#     │       │       BlpImagePlugin.py
#     │       │       BmpImagePlugin.py
#     │       │       BufrStubImagePlugin.py
#     │       │       ContainerIO.py
#     │       │       CurImagePlugin.py
#     │       │       DcxImagePlugin.py
#     │       │       DdsImagePlugin.py
#     │       │       EpsImagePlugin.py
#     │       │       ExifTags.py
#     │       │       FitsImagePlugin.py
#     │       │       FitsStubImagePlugin.py
#     │       │       FliImagePlugin.py
#     │       │       FontFile.py
#     │       │       FpxImagePlugin.py
#     │       │       FtexImagePlugin.py
#     │       │       GbrImagePlugin.py
#     │       │       GdImageFile.py
#     │       │       GifImagePlugin.py
#     │       │       GimpGradientFile.py
#     │       │       GimpPaletteFile.py
#     │       │       GribStubImagePlugin.py
#     │       │       Hdf5StubImagePlugin.py
#     │       │       IcnsImagePlugin.py
#     │       │       IcoImagePlugin.py
#     │       │       ImImagePlugin.py
#     │       │       Image.py
#     │       │       ImageChops.py
#     │       │       ImageCms.py
#     │       │       ImageColor.py
#     │       │       ImageDraw.py
#     │       │       ImageDraw2.py
#     │       │       ImageEnhance.py
#     │       │       ImageFile.py
#     │       │       ImageFilter.py
#     │       │       ImageFont.py
#     │       │       ImageGrab.py
#     │       │       ImageMath.py
#     │       │       ImageMode.py
#     │       │       ImageMorph.py
#     │       │       ImageOps.py
#     │       │       ImagePalette.py
#     │       │       ImagePath.py
#     │       │       ImageQt.py
#     │       │       ImageSequence.py
#     │       │       ImageShow.py
#     │       │       ImageStat.py
#     │       │       ImageTk.py
#     │       │       ImageTransform.py
#     │       │       ImageWin.py
#     │       │       ImtImagePlugin.py
#     │       │       IptcImagePlugin.py
#     │       │       Jpeg2KImagePlugin.py
#     │       │       JpegImagePlugin.py
#     │       │       JpegPresets.py
#     │       │       McIdasImagePlugin.py
#     │       │       MicImagePlugin.py
#     │       │       MpegImagePlugin.py
#     │       │       MpoImagePlugin.py
#     │       │       MspImagePlugin.py
#     │       │       PSDraw.py
#     │       │       PaletteFile.py
#     │       │       PalmImagePlugin.py
#     │       │       PcdImagePlugin.py
#     │       │       PcfFontFile.py
#     │       │       PcxImagePlugin.py
#     │       │       PdfImagePlugin.py
#     │       │       PdfParser.py
#     │       │       PixarImagePlugin.py
#     │       │       PngImagePlugin.py
#     │       │       PpmImagePlugin.py
#     │       │       PsdImagePlugin.py
#     │       │       PyAccess.py
#     │       │       SgiImagePlugin.py
#     │       │       SpiderImagePlugin.py
#     │       │       SunImagePlugin.py
#     │       │       TarIO.py
#     │       │       TgaImagePlugin.py
#     │       │       TiffImagePlugin.py
#     │       │       TiffTags.py
#     │       │       WalImageFile.py
#     │       │       WebPImagePlugin.py
#     │       │       WmfImagePlugin.py
#     │       │       XVThumbImagePlugin.py
#     │       │       XbmImagePlugin.py
#     │       │       XpmImagePlugin.py
#     │       │       __init__.py
#     │       │       __main__.py
#     │       │       _binary.py
#     │       │       _deprecate.py
#     │       │       _imaging.cp311-win_amd64.pyd
#     │       │       _imagingcms.cp311-win_amd64.pyd
#     │       │       _imagingft.cp311-win_amd64.pyd
#     │       │       _imagingmath.cp311-win_amd64.pyd
#     │       │       _imagingmorph.cp311-win_amd64.pyd
#     │       │       _imagingtk.cp311-win_amd64.pyd
#     │       │       _tkinter_finder.py
#     │       │       _util.py
#     │       │       _version.py
#     │       │       _webp.cp311-win_amd64.pyd
#     │       │       features.py
#     │       ├── Pillow-9.3.0.dist-info/
#     │       │       INSTALLER
#     │       │       LICENSE
#     │       │       METADATA
#     │       │       RECORD
#     │       │       REQUESTED
#     │       │       WHEEL
#     │       │       top_level.txt
#     │       │       zip-safe
#     │       ├── Pygments-2.13.0.dist-info/
#     │       │       AUTHORS
#     │       │       INSTALLER
#     │       │       LICENSE
#     │       │       METADATA
#     │       │       RECORD
#     │       │       WHEEL
#     │       │       entry_points.txt
#     │       │       top_level.txt
#     │       ├── __pycache__/
#     │       │       decorator.cpython-311.pyc
#     │       │       entrypoints.cpython-311.pyc
#     │       │       ipykernel_launcher.cpython-311.pyc
#     │       │       jupyter.cpython-311.pyc
#     │       │       nest_asyncio.cpython-311.pyc
#     │       │       nvidia_smi.cpython-311.pyc
#     │       │       pickleshare.cpython-311.pyc
#     │       │       pynvml.cpython-311.pyc
#     │       │       pythoncom.cpython-311.pyc
#     │       │       six.cpython-311.pyc
#     │       ├── _distutils_hack/
#     │       │   └── __pycache__/
#     │       │           __init__.cpython-311.pyc
#     │       │           override.cpython-311.pyc
#     │       │       __init__.py
#     │       │       override.py
#     │       ├── adodbapi/
#     │       │   ├── __pycache__/
#     │       │   │       __init__.cpython-311.pyc
#     │       │   │       ado_consts.cpython-311.pyc
#     │       │   │       adodbapi.cpython-311.pyc
#     │       │   │       apibase.cpython-311.pyc
#     │       │   │       is64bit.cpython-311.pyc
#     │       │   │       process_connect_string.cpython-311.pyc
#     │       │   │       remote.cpython-311.pyc
#     │       │   │       schema_table.cpython-311.pyc
#     │       │   │       setup.cpython-311.pyc
#     │       │   ├── examples/
#     │       │   │   └── __pycache__/
#     │       │   │           db_print.cpython-311.pyc
#     │       │   │           db_table_names.cpython-311.pyc
#     │       │   │           xls_read.cpython-311.pyc
#     │       │   │           xls_write.cpython-311.pyc
#     │       │   │       db_print.py
#     │       │   │       db_table_names.py
#     │       │   │       xls_read.py
#     │       │   │       xls_write.py
#     │       │   └── test/
#     │       │       └── __pycache__/
#     │       │               adodbapitest.cpython-311.pyc
#     │       │               adodbapitestconfig.cpython-311.pyc
#     │       │               dbapi20.cpython-311.pyc
#     │       │               is64bit.cpython-311.pyc
#     │       │               setuptestframework.cpython-311.pyc
#     │       │               test_adodbapi_dbapi20.cpython-311.pyc
#     │       │               tryconnection.cpython-311.pyc
#     │       │           adodbapitest.py
#     │       │           adodbapitestconfig.py
#     │       │           dbapi20.py
#     │       │           is64bit.py
#     │       │           setuptestframework.py
#     │       │           test_adodbapi_dbapi20.py
#     │       │           tryconnection.py
#     │       │       __init__.py
#     │       │       ado_consts.py
#     │       │       adodbapi.py
#     │       │       apibase.py
#     │       │       is64bit.py
#     │       │       license.txt
#     │       │       process_connect_string.py
#     │       │       readme.txt
#     │       │       remote.py
#     │       │       schema_table.py
#     │       │       setup.py
#     │       ├── asttokens/
#     │       │   └── __pycache__/
#     │       │           __init__.cpython-311.pyc
#     │       │           astroid_compat.cpython-311.pyc
#     │       │           asttokens.cpython-311.pyc
#     │       │           line_numbers.cpython-311.pyc
#     │       │           mark_tokens.cpython-311.pyc
#     │       │           util.cpython-311.pyc
#     │       │           version.cpython-311.pyc
#     │       │       __init__.py
#     │       │       astroid_compat.py
#     │       │       asttokens.py
#     │       │       line_numbers.py
#     │       │       mark_tokens.py
#     │       │       py.typed
#     │       │       util.py
#     │       │       version.py
#     │       ├── asttokens-2.2.1.dist-info/
#     │       │       INSTALLER
#     │       │       LICENSE
#     │       │       METADATA
#     │       │       RECORD
#     │       │       WHEEL
#     │       │       top_level.txt
#     │       ├── backcall/
#     │       │   └── __pycache__/
#     │       │           __init__.cpython-311.pyc
#     │       │           _signatures.cpython-311.pyc
#     │       │           backcall.cpython-311.pyc
#     │       │       __init__.py
#     │       │       _signatures.py
#     │       │       backcall.py
#     │       ├── backcall-0.2.0.dist-info/
#     │       │       INSTALLER
#     │       │       LICENSE
#     │       │       METADATA
#     │       │       RECORD
#     │       │       WHEEL
#     │       ├── cffi/
#     │       │   └── __pycache__/
#     │       │           __init__.cpython-311.pyc
#     │       │           api.cpython-311.pyc
#     │       │           backend_ctypes.cpython-311.pyc
#     │       │           cffi_opcode.cpython-311.pyc
#     │       │           commontypes.cpython-311.pyc
#     │       │           cparser.cpython-311.pyc
#     │       │           error.cpython-311.pyc
#     │       │           ffiplatform.cpython-311.pyc
#     │       │           lock.cpython-311.pyc
#     │       │           model.cpython-311.pyc
#     │       │           pkgconfig.cpython-311.pyc
#     │       │           recompiler.cpython-311.pyc
#     │       │           setuptools_ext.cpython-311.pyc
#     │       │           vengine_cpy.cpython-311.pyc
#     │       │           vengine_gen.cpython-311.pyc
#     │       │           verifier.cpython-311.pyc
#     │       │       __init__.py
#     │       │       _cffi_errors.h
#     │       │       _cffi_include.h
#     │       │       _embedding.h
#     │       │       api.py
#     │       │       backend_ctypes.py
#     │       │       cffi_opcode.py
#     │       │       commontypes.py
#     │       │       cparser.py
#     │       │       error.py
#     │       │       ffiplatform.py
#     │       │       lock.py
#     │       │       model.py
#     │       │       parse_c_type.h
#     │       │       pkgconfig.py
#     │       │       recompiler.py
#     │       │       setuptools_ext.py
#     │       │       vengine_cpy.py
#     │       │       vengine_gen.py
#     │       │       verifier.py
#     │       ├── cffi-1.15.1.dist-info/
#     │       │       INSTALLER
#     │       │       LICENSE
#     │       │       METADATA
#     │       │       RECORD
#     │       │       WHEEL
#     │       │       entry_points.txt
#     │       │       top_level.txt
#     │       ├── colorama/
#     │       │   ├── __pycache__/
#     │       │   │       __init__.cpython-311.pyc
#     │       │   │       ansi.cpython-311.pyc
#     │       │   │       ansitowin32.cpython-311.pyc
#     │       │   │       initialise.cpython-311.pyc
#     │       │   │       win32.cpython-311.pyc
#     │       │   │       winterm.cpython-311.pyc
#     │       │   └── tests/
#     │       │       └── __pycache__/
#     │       │               __init__.cpython-311.pyc
#     │       │               ansi_test.cpython-311.pyc
#     │       │               ansitowin32_test.cpython-311.pyc
#     │       │               initialise_test.cpython-311.pyc
#     │       │               isatty_test.cpython-311.pyc
#     │       │               utils.cpython-311.pyc
#     │       │               winterm_test.cpython-311.pyc
#     │       │           __init__.py
#     │       │           ansi_test.py
#     │       │           ansitowin32_test.py
#     │       │           initialise_test.py
#     │       │           isatty_test.py
#     │       │           utils.py
#     │       │           winterm_test.py
#     │       │       __init__.py
#     │       │       ansi.py
#     │       │       ansitowin32.py
#     │       │       initialise.py
#     │       │       win32.py
#     │       │       winterm.py
#     │       ├── colorama-0.4.6.dist-info/
#     │       │   └── licenses/
#     │       │           LICENSE.txt
#     │       │       INSTALLER
#     │       │       METADATA
#     │       │       RECORD
#     │       │       WHEEL
#     │       ├── comm/
#     │       │   └── __pycache__/
#     │       │           __init__.cpython-311.pyc
#     │       │           base_comm.cpython-311.pyc
#     │       │       __init__.py
# ...
#     │       │   │       └── __pycache__/
#     │       │   │               testSHFileOperation.cpython-311.pyc
#     │       │   │               testShellFolder.cpython-311.pyc
#     │       │   │               testShellItem.cpython-311.pyc
#     │       │   │           testSHFileOperation.py
#     │       │   │           testShellFolder.py
#     │       │   │           testShellItem.py
#     │       │   │       __init__.py
#     │       │   │       shell.pyd
#     │       │   │       shellcon.py
#     │       │   └── taskscheduler/
#     │       │       ├── __pycache__/
#     │       │       │       __init__.cpython-311.pyc
#     │       │       └── test/
#     │       │           └── __pycache__/
#     │       │                   test_addtask.cpython-311.pyc
#     │       │                   test_addtask_1.cpython-311.pyc
#     │       │                   test_addtask_2.cpython-311.pyc
#     │       │                   test_localsystem.cpython-311.pyc
#     │       │               test_addtask.py
#     │       │               test_addtask_1.py
#     │       │               test_addtask_2.py
#     │       │               test_localsystem.py
#     │       │           __init__.py
#     │       │           taskscheduler.pyd
#     │       └── zmq/
#     │           ├── __pycache__/
#     │           │       __init__.cpython-311.pyc
#     │           │       _future.cpython-311.pyc
#     │           │       _typing.cpython-311.pyc
#     │           │       asyncio.cpython-311.pyc
#     │           │       constants.cpython-311.pyc
#     │           │       decorators.cpython-311.pyc
#     │           │       error.cpython-311.pyc
#     │           ├── auth/
#     │           │   └── __pycache__/
#     │           │           __init__.cpython-311.pyc
#     │           │           asyncio.cpython-311.pyc
#     │           │           base.cpython-311.pyc
#     │           │           certs.cpython-311.pyc
#     │           │           ioloop.cpython-311.pyc
#     │           │           thread.cpython-311.pyc
#     │           │       __init__.py
#     │           │       asyncio.py
#     │           │       base.py
#     │           │       certs.py
#     │           │       ioloop.py
#     │           │       thread.py
#     │           ├── backend/
#     │           │   ├── __pycache__/
#     │           │   │       __init__.cpython-311.pyc
#     │           │   │       select.cpython-311.pyc
#     │           │   ├── cffi/
#     │           │   │   └── __pycache__/
#     │           │   │           __init__.cpython-311.pyc
#     │           │   │           _poll.cpython-311.pyc
#     │           │   │           context.cpython-311.pyc
#     │           │   │           devices.cpython-311.pyc
#     │           │   │           error.cpython-311.pyc
#     │           │   │           message.cpython-311.pyc
#     │           │   │           socket.cpython-311.pyc
#     │           │   │           utils.cpython-311.pyc
#     │           │   │       __init__.py
#     │           │   │       _cdefs.h
#     │           │   │       _poll.py
#     │           │   │       context.py
#     │           │   │       devices.py
#     │           │   │       error.py
#     │           │   │       message.py
#     │           │   │       socket.py
#     │           │   │       utils.py
#     │           │   └── cython/
#     │           │       └── __pycache__/
#     │           │               __init__.cpython-311.pyc
#     │           │           __init__.pxd
#     │           │           __init__.py
#     │           │           _device.cp311-win_amd64.pyd
#     │           │           _poll.cp311-win_amd64.pyd
#     │           │           _proxy_steerable.cp311-win_amd64.pyd
#     │           │           _version.cp311-win_amd64.pyd
#     │           │           checkrc.pxd
#     │           │           constant_enums.pxi
#     │           │           context.cp311-win_amd64.pyd
#     │           │           context.pxd
#     │           │           error.cp311-win_amd64.pyd
#     │           │           libzmq.pxd
#     │           │           message.cp311-win_amd64.pyd
#     │           │           message.pxd
#     │           │           socket.cp311-win_amd64.pyd
#     │           │           socket.pxd
#     │           │           utils.cp311-win_amd64.pyd
#     │           │       __init__.py
#     │           │       __init__.pyi
#     │           │       select.py
#     │           ├── devices/
#     │           │   └── __pycache__/
#     │           │           __init__.cpython-311.pyc
#     │           │           basedevice.cpython-311.pyc
#     │           │           monitoredqueue.cpython-311.pyc
#     │           │           monitoredqueuedevice.cpython-311.pyc
#     │           │           proxydevice.cpython-311.pyc
#     │           │           proxysteerabledevice.cpython-311.pyc
#     │           │       __init__.py
#     │           │       basedevice.py
#     │           │       monitoredqueue.cp311-win_amd64.pyd
#     │           │       monitoredqueue.pxd
#     │           │       monitoredqueue.py
#     │           │       monitoredqueuedevice.py
#     │           │       proxydevice.py
#     │           │       proxysteerabledevice.py
#     │           ├── eventloop/
#     │           │   ├── __pycache__/
#     │           │   │       __init__.cpython-311.pyc
#     │           │   │       _deprecated.cpython-311.pyc
#     │           │   │       future.cpython-311.pyc
#     │           │   │       ioloop.cpython-311.pyc
#     │           │   │       zmqstream.cpython-311.pyc
#     │           │   └── minitornado/
#     │           │       ├── __pycache__/
#     │           │       │       __init__.cpython-311.pyc
#     │           │       │       concurrent.cpython-311.pyc
#     │           │       │       ioloop.cpython-311.pyc
#     │           │       │       log.cpython-311.pyc
#     │           │       │       stack_context.cpython-311.pyc
#     │           │       │       util.cpython-311.pyc
#     │           │       └── platform/
#     │           │           └── __pycache__/
#     │           │                   __init__.cpython-311.pyc
#     │           │                   auto.cpython-311.pyc
#     │           │                   common.cpython-311.pyc
#     │           │                   interface.cpython-311.pyc
#     │           │                   posix.cpython-311.pyc
#     │           │                   windows.cpython-311.pyc
#     │           │               __init__.py
#     │           │               auto.py
#     │           │               common.py
#     │           │               interface.py
#     │           │               posix.py
#     │           │               windows.py
#     │           │           __init__.py
#     │           │           concurrent.py
#     │           │           ioloop.py
#     │           │           log.py
#     │           │           stack_context.py
#     │           │           util.py
#     │           │       __init__.py
#     │           │       _deprecated.py
#     │           │       future.py
#     │           │       ioloop.py
#     │           │       zmqstream.py
#     │           ├── green/
#     │           │   ├── __pycache__/
#     │           │   │       __init__.cpython-311.pyc
#     │           │   │       core.cpython-311.pyc
#     │           │   │       device.cpython-311.pyc
#     │           │   │       poll.cpython-311.pyc
#     │           │   └── eventloop/
#     │           │       └── __pycache__/
#     │           │               __init__.cpython-311.pyc
#     │           │               ioloop.cpython-311.pyc
#     │           │               zmqstream.cpython-311.pyc
#     │           │           __init__.py
#     │           │           ioloop.py
#     │           │           zmqstream.py
#     │           │       __init__.py
#     │           │       core.py
#     │           │       device.py
#     │           │       poll.py
#     │           ├── log/
#     │           │   └── __pycache__/
#     │           │           __init__.cpython-311.pyc
#     │           │           __main__.cpython-311.pyc
#     │           │           handlers.cpython-311.pyc
#     │           │       __init__.py
#     │           │       __main__.py
#     │           │       handlers.py
#     │           ├── ssh/
#     │           │   └── __pycache__/
#     │           │           __init__.cpython-311.pyc
#     │           │           forward.cpython-311.pyc
#     │           │           tunnel.cpython-311.pyc
#     │           │       __init__.py
#     │           │       forward.py
#     │           │       tunnel.py
#     │           ├── sugar/
#     │           │   └── __pycache__/
#     │           │           __init__.cpython-311.pyc
#     │           │           attrsettr.cpython-311.pyc
#     │           │           context.cpython-311.pyc
#     │           │           frame.cpython-311.pyc
#     │           │           poll.cpython-311.pyc
#     │           │           socket.cpython-311.pyc
#     │           │           stopwatch.cpython-311.pyc
#     │           │           tracker.cpython-311.pyc
#     │           │           version.cpython-311.pyc
#     │           │       __init__.py
#     │           │       __init__.pyi
#     │           │       attrsettr.py
#     │           │       context.py
#     │           │       frame.py
#     │           │       poll.py
#     │           │       socket.py
#     │           │       stopwatch.py
#     │           │       tracker.py
#     │           │       version.py
#     │           ├── tests/
#     │           │   └── __pycache__/
#     │           │           __init__.cpython-311.pyc
#     │           │           conftest.cpython-311.pyc
#     │           │           test_asyncio.cpython-311.pyc
#     │           │           test_auth.cpython-311.pyc
#     │           │           test_cffi_backend.cpython-311.pyc
#     │           │           test_constants.cpython-311.pyc
#     │           │           test_context.cpython-311.pyc
#     │           │           test_cython.cpython-311.pyc
#     │           │           test_decorators.cpython-311.pyc
#     │           │           test_device.cpython-311.pyc
#     │           │           test_draft.cpython-311.pyc
#     │           │           test_error.cpython-311.pyc
#     │           │           test_etc.cpython-311.pyc
#     │           │           test_ext.cpython-311.pyc
#     │           │           test_future.cpython-311.pyc
#     │           │           test_imports.cpython-311.pyc
#     │           │           test_includes.cpython-311.pyc
#     │           │           test_ioloop.cpython-311.pyc
#     │           │           test_log.cpython-311.pyc
#     │           │           test_message.cpython-311.pyc
#     │           │           test_monitor.cpython-311.pyc
#     │           │           test_monqueue.cpython-311.pyc
#     │           │           test_multipart.cpython-311.pyc
#     │           │           test_mypy.cpython-311.pyc
#     │           │           test_pair.cpython-311.pyc
#     │           │           test_poll.cpython-311.pyc
#     │           │           test_proxy_steerable.cpython-311.pyc
#     │           │           test_pubsub.cpython-311.pyc
#     │           │           test_reqrep.cpython-311.pyc
#     │           │           test_retry_eintr.cpython-311.pyc
#     │           │           test_security.cpython-311.pyc
#     │           │           test_socket.cpython-311.pyc
#     │           │           test_ssh.cpython-311.pyc
#     │           │           test_version.cpython-311.pyc
#     │           │           test_win32_shim.cpython-311.pyc
#     │           │           test_z85.cpython-311.pyc
#     │           │           test_zmqstream.cpython-311.pyc
#     │           │       __init__.py
#     │           │       conftest.py
#     │           │       cython_ext.pyx
#     │           │       test_asyncio.py
#     │           │       test_auth.py
#     │           │       test_cffi_backend.py
#     │           │       test_constants.py
#     │           │       test_context.py
#     │           │       test_cython.py
#     │           │       test_decorators.py
#     │           │       test_device.py
#     │           │       test_draft.py
#     │           │       test_error.py
#     │           │       test_etc.py
#     │           │       test_ext.py
#     │           │       test_future.py
#     │           │       test_imports.py
#     │           │       test_includes.py
#     │           │       test_ioloop.py
#     │           │       test_log.py
#     │           │       test_message.py
#     │           │       test_monitor.py
#     │           │       test_monqueue.py
#     │           │       test_multipart.py
#     │           │       test_mypy.py
#     │           │       test_pair.py
#     │           │       test_poll.py
#     │           │       test_proxy_steerable.py
#     │           │       test_pubsub.py
#     │           │       test_reqrep.py
#     │           │       test_retry_eintr.py
#     │           │       test_security.py
#     │           │       test_socket.py
#     │           │       test_ssh.py
#     │           │       test_version.py
#     │           │       test_win32_shim.py
#     │           │       test_z85.py
#     │           │       test_zmqstream.py
#     │           └── utils/
#     │               └── __pycache__/
#     │                       __init__.cpython-311.pyc
#     │                       garbage.cpython-311.pyc
#     │                       interop.cpython-311.pyc
#     │                       jsonapi.cpython-311.pyc
#     │                       monitor.cpython-311.pyc
#     │                       strtypes.cpython-311.pyc
#     │                       win32.cpython-311.pyc
#     │                       z85.cpython-311.pyc
#     │                   __init__.py
#     │                   buffers.pxd
#     │                   compiler.json
#     │                   config.json
#     │                   garbage.py
#     │                   getpid_compat.h
#     │                   interop.py
#     │                   ipcmaxlen.h
#     │                   jsonapi.py
#     │                   monitor.py
#     │                   mutex.h
#     │                   pyversion_compat.h
#     │                   strtypes.py
#     │                   win32.py
#     │                   z85.py
#     │                   zmq_compat.h
#     │               __init__.pxd
#     │               __init__.py
#     │               __init__.pyi
#     │               _future.py
#     │               _typing.py
#     │               asyncio.py
#     │               constants.py
#     │               decorators.py
#     │               error.py
#     │               py.typed
#     │           PyWin32.chm
#     │           _cffi_backend.cp311-win_amd64.pyd
#     │           decorator.py
#     │           distutils-precedence.pth
#     │           entrypoints.py
#     │           ipykernel_launcher.py
#     │           jupyter.py
#     │           nest_asyncio.py
#     │           nvidia_smi.py
#     │           pickleshare.py
#     │           pynvml.py
#     │           pythoncom.py
#     │           pywin32.pth
#     │           pywin32.version.txt
#     │           scipy-1.10.1-cp311-cp311-win_amd64.whl
#     │           six.py
#     ├── Scripts/
#     │   └── __pycache__/
#     │           pywin32_postinstall.cpython-311.pyc
#     │           pywin32_testall.cpython-311.pyc
#     │       Activate.ps1
#     │       activate
#     │       activate.bat
#     │       deactivate.bat
#     │       f2py.exe
#     │       ipython.exe
#     │       ipython3.10.exe
#     │       ipython3.exe
#     │       jupyter-kernel.exe
#     │       jupyter-kernelspec.exe
#     │       jupyter-migrate.exe
#     │       jupyter-run.exe
#     │       jupyter-troubleshoot.exe
#     │       jupyter.exe
#     │       pip.exe
#     │       pip3.10.exe
#     │       pip3.11.exe
#     │       pip3.exe
#     │       pygmentize.exe
#     │       python.exe
#     │       pythonw.exe
#     │       pywin32_postinstall.py
#     │       pywin32_testall.py
#     └── share/
#         ├── jupyter/
#         │   └── kernels/
#         │       └── python3/
#         │               kernel.json
#         │               logo-32x32.png
#         │               logo-64x64.png
#         │               logo-svg.svg
#         └── man/
#             └── man1/
#                     ipython.1
#         pyvenv.cfg
#     .env.development
#     .gitignore
#     8_puzzle.ipynb
#     README.md
#     ascii_filetree.ipynb
#     gauss.ipynb
#     search.py
#     tic_tac_toe.ipynb
#     tmp.ipynb
